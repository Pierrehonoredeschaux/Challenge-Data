# %%
! pip install xgboost
import xgboost as xgb
import pandas as pd 
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
from scipy import stats 
import matplotlib.pyplot as plt
import sys
import warnings

warnings.filterwarnings("ignore")

pd.options.mode.chained_assignment = None  

#####################################  IMPORTATION DONNEES ##################################################

X_test = pd.read_csv('Data/X_test_BEhvxAN.csv')
X_test2 = X_test
X_train = pd.read_csv('Data/X_train_J01Z4CN.csv') 
y_train = pd.read_csv('Data/y_train_OXxrJt1.csv') 


#####################################  TRAITEMENT DES DONNEES ###############################################

X_train = X_train.merge(y_train, on='id_annonce')


#------------ Codage de la variable code postal ---------------


X_train.insert(1,"prix_par_m2", 0)

b = X_train['prix_par_m2']
e = X_train['postal_code']

# donnees des prix moyen par departement : https://www.meilleursagents.com/prix-immobilier/

for i in range (0,len(X_train['postal_code'])): # AFFECTATION DU PRIX PAR RAPPORT AU DEPARTEMENT
        if e[i]< 2000 :
            b[i] = 2666 
            
        elif e[i]>= 2000 and e[i] <3000 :
            b[i] = 1266 
            
        elif e[i]>= 3000 and e[i] <4000 :
            b[i] = 1232
            
        elif e[i]>= 4000 and e[i] <5000 :
            b[i] = 1987 
            
        elif e[i]>= 5000 and e[i] <6000 :
            b[i] = 2887
            
        elif e[i]>= 6000 and e[i] <7000 :
            b[i] = 5000
            
        elif e[i]>= 7000 and e[i] <8000 :
            b[i] = 1741 
            
        elif e[i]>= 8000 and e[i] <9000 :
            b[i] = 1224 
            
        elif e[i]>= 9000 and e[i] <10000 :
            b[i] = 1422 
            
        elif e[i]>= 10000 and e[i] <11000 :
            b[i] = 1805 
            
        elif e[i]>= 11000 and e[i] <12000 :
            b[i] = 2072 
            
        elif e[i]>= 12000 and e[i] <13000 :
            b[i] = 1812 
            
        elif e[i]>= 13000 and e[i] <14000 :
            b[i] = 3667 
            
        elif e[i]>= 14000 and e[i] <15000 :
            b[i] = 3348 
            
        elif e[i]>= 15000 and e[i] <16000 :
            b[i] = 1456
        
        elif e[i]>= 16000 and e[i] <17000 :
            b[i] = 1566
        
        elif e[i]>= 17000 and e[i] <18000 :
            b[i] = 3954
            
        elif e[i]>= 18000 and e[i] <19000 :
            b[i] = 1356
        
        elif e[i]>= 19000 and e[i] <20000 :
            b[i] = 1480
        
        elif e[i]>= 20000 and e[i] <21000 :
            b[i] = 4016
        
        elif e[i]>= 21000 and e[i] <22000 :
            b[i] = 2379
        
        elif e[i]>= 22000 and e[i] <23000 :
            b[i] = 2616
        
        elif e[i]>= 23000 and e[i] <24000 :
            b[i] = 1005
            
        elif e[i]>= 24000 and e[i] <25000 :
            b[i] = 1704
            
        elif e[i]>= 25000 and e[i] <26000 :
            b[i] = 2035
            
        elif e[i]>= 26000 and e[i] <27000 :
            b[i] = 2092
            
        elif e[i]>= 27000 and e[i] <28000 :
            b[i] = 1964
            
        elif e[i]>= 28000 and e[i] <29000 :
            b[i] = 2056
            
        elif e[i]>= 29000 and e[i] <30000 :
            b[i] = 2414
            
        elif e[i]>= 30000 and e[i] <31000 :
            b[i] = 2421
            
        elif e[i]>= 31000 and e[i] <32000 :
            b[i] = 3343
            
        elif e[i]>= 32000 and e[i] <33000 :
            b[i] = 1487
            
        elif e[i]>= 33000 and e[i] <34000 :
            b[i] = 4137
            
        elif e[i]>= 34000 and e[i] <35000 :
            b[i] = 3397
            
        elif e[i]>= 35000 and e[i] <36000 :
            b[i] = 3627
            
        elif e[i]>= 36000 and e[i] <37000 :
            b[i] = 1235
            
        elif e[i]>= 37000 and e[i] <38000 :
            b[i] = 2502
            
        elif e[i]>= 38000 and e[i] <39000 :
            b[i] = 2686
            
        elif e[i]>= 39000 and e[i] <40000 :
            b[i] = 1567
            
        elif e[i]>= 40000 and e[i] <41000 :
            b[i] = 3954
        
        elif e[i]>= 41000 and e[i] <42000 :
            b[i] = 1507
            
        elif e[i]>= 42000 and e[i] <43000 :
            b[i] =1546
            
        elif e[i]>= 43000 and e[i] <44000 :
            b[i] = 1519
            
        elif e[i]>= 44000 and e[i] <45000 :
            b[i] = 3950
            
        elif e[i]>= 45000 and e[i] <46000 :
            b[i] = 2180
            
        elif e[i]>= 46000 and e[i] <47000 :
            b[i] = 1468
            
        elif e[i]>= 47000 and e[i] <48000 :
            b[i] = 1530
            
        elif e[i]>= 48000 and e[i] <49000 :
            b[i] = 1501
            
        elif e[i]>= 49000 and e[i] <50000 :
            b[i] = 2913
            
        elif e[i]>= 50000 and e[i] <51000 :
            b[i] = 2369
            
        elif e[i]>= 51000 and e[i] <52000 :
            b[i] = 2382
            
        elif e[i]>= 52000 and e[i] <53000 :
            b[i] = 1201
            
        elif e[i]>= 53000 and e[i] <54000 :
            b[i] = 1951
            
        elif e[i]>= 54000 and e[i] <55000 :
            b[i] = 1973
            
        elif e[i]>= 55000 and e[i] <56000 :
            b[i] = 1231
            
        elif e[i]>= 56000 and e[i] <57000 :
            b[i] = 3428
            
        elif e[i]>= 57000 and e[i] <58000 :
            b[i] = 1940
            
        elif e[i]>= 58000 and e[i] <59000 :
            b[i] = 1020
            
        elif e[i]>= 59000 and e[i] <60000 :
            b[i] = 2619
            
        elif e[i]>= 60000 and e[i] <61000 :
            b[i] = 2294
            
        elif e[i]>= 61000 and e[i] <62000 :
            b[i] = 1547
            
        elif e[i]>= 62000 and e[i] <63000 :
            b[i] = 2433
            
        elif e[i]>= 63000 and e[i] <64000 :
            b[i] = 2215
            
        elif e[i]>= 64000 and e[i] <65000 :
            b[i] = 4323
            
        elif e[i]>= 65000 and e[i] <66000 :
            b[i] = 1846
            
        elif e[i]>= 66000 and e[i] <67000 :
            b[i] = 2364
            
        elif e[i]>= 67000 and e[i] <68000 :
            b[i] = 3244
            
        elif e[i]>= 68000 and e[i] <69000 :
            b[i] = 1874
            
        elif e[i]>= 69000 and e[i] <70000 :
            b[i] = 4275
            
        elif e[i]>= 70000 and e[i] <71000 :
            b[i] = 1136
            
        elif e[i]>= 71000 and e[i] <72000 :
            b[i] = 1363
            
        elif e[i]>= 72000 and e[i] <73000 :
            b[i] = 1705
            
        elif e[i]>= 73000 and e[i] <74000 :
            b[i] = 4446
            
        elif e[i]>= 74000 and e[i] <75000 :
            b[i] =4604
            
        elif e[i]>= 75000 and e[i] <76000 :
            b[i] = 10346
            
        elif e[i]>= 76000 and e[i] <77000 :
            b[i] = 2266
            
        elif e[i]>= 77000 and e[i] <78000 :
            b[i] = 3391
            
        elif e[i]>= 78000 and e[i] <79000 :
            b[i] = 4977
            
        elif e[i]>= 79000 and e[i] <80000 :
            b[i] = 1684
            
        elif e[i]>= 80000 and e[i] <81000 :
            b[i] = 2354
            
        elif e[i]>= 81000 and e[i] <82000 :
            b[i] = 1740
            
        elif e[i]>= 82000 and e[i] <83000 :
            b[i] = 1707
            
        elif e[i]>= 83000 and e[i] <84000 :
            b[i] = 4107
            
        elif e[i]>= 84000 and e[i] <85000 :
            b[i] = 2347
            
        elif e[i]>= 85000 and e[i] <86000 :
            b[i] = 3188
            
        elif e[i]>= 86000 and e[i] <87000 :
            b[i] = 2182
            
        elif e[i]>= 87000 and e[i] <88000 :
            b[i] = 1817
            
        elif e[i]>= 88000 and e[i] <89000 :
            b[i] = 1579
            
        elif e[i]>= 89000 and e[i] <90000 :
            b[i] = 1348
            
        elif e[i]>= 90000 and e[i] <91000 :
            b[i] = 1403
            
        elif e[i]>= 91000 and e[i] <92000 :
            b[i] = 3288
            
        elif e[i]>= 92000 and e[i] <93000 :
            b[i] = 7250
            
        elif e[i]>= 93000 and e[i] <94000 :
            b[i] = 4539
            
        elif e[i]>= 94000 and e[i] <95000 :
            b[i] = 5622
            
        elif e[i]>= 95000 and e[i] <96000 :
            b[i] = 3519

            

X_train.insert(1,"prix_size", 0)  
e= X_train["prix_size"]
f= X_train["prix_par_m2"]
s = X_train["size"]

for i in range (0,len(X_train['size'])): ## PRIX MOYEN DE LA SUPERFICIE 
    e[i] = f[i] * s[i]

# Dans X_test maintenant

X_test.insert(1,"prix_par_m2", 0)

b = X_test['prix_par_m2']
e = X_test['postal_code']


for i in range (0,len(X_test['postal_code'])): ## AFFECTATION DU PRIX PAR RAPPORT AU DEPARTEMENT
        if e[i]< 2000 :
            b[i] = 2666 
            
        elif e[i]>= 2000 and e[i] <3000 :
            b[i] = 1266 
            
        elif e[i]>= 3000 and e[i] <4000 :
            b[i] = 1232
            
        elif e[i]>= 4000 and e[i] <5000 :
            b[i] = 1987 
            
        elif e[i]>= 5000 and e[i] <6000 :
            b[i] = 2887
            
        elif e[i]>= 6000 and e[i] <7000 :
            b[i] = 5000
            
        elif e[i]>= 7000 and e[i] <8000 :
            b[i] = 1741 
            
        elif e[i]>= 8000 and e[i] <9000 :
            b[i] = 1224 
            
        elif e[i]>= 9000 and e[i] <10000 :
            b[i] = 1422 
            
        elif e[i]>= 10000 and e[i] <11000 :
            b[i] = 1805 
            
        elif e[i]>= 11000 and e[i] <12000 :
            b[i] = 2072 
            
        elif e[i]>= 12000 and e[i] <13000 :
            b[i] = 1812 
            
        elif e[i]>= 13000 and e[i] <14000 :
            b[i] = 3667 
            
        elif e[i]>= 14000 and e[i] <15000 :
            b[i] = 3348 
            
        elif e[i]>= 15000 and e[i] <16000 :
            b[i] = 1456
        
        elif e[i]>= 16000 and e[i] <17000 :
            b[i] = 1566
        
        elif e[i]>= 17000 and e[i] <18000 :
            b[i] = 3954
            
        elif e[i]>= 18000 and e[i] <19000 :
            b[i] = 1356
        
        elif e[i]>= 19000 and e[i] <20000 :
            b[i] = 1480
        
        elif e[i]>= 20000 and e[i] <21000 :
            b[i] = 4016
        
        elif e[i]>= 21000 and e[i] <22000 :
            b[i] = 2379
        
        elif e[i]>= 22000 and e[i] <23000 :
            b[i] = 2616
        
        elif e[i]>= 23000 and e[i] <24000 :
            b[i] = 1005
            
        elif e[i]>= 24000 and e[i] <25000 :
            b[i] = 1704
            
        elif e[i]>= 25000 and e[i] <26000 :
            b[i] = 2035
            
        elif e[i]>= 26000 and e[i] <27000 :
            b[i] = 2092
            
        elif e[i]>= 27000 and e[i] <28000 :
            b[i] = 1964
            
        elif e[i]>= 28000 and e[i] <29000 :
            b[i] = 2056
            
        elif e[i]>= 29000 and e[i] <30000 :
            b[i] = 2414
            
        elif e[i]>= 30000 and e[i] <31000 :
            b[i] = 2421
            
        elif e[i]>= 31000 and e[i] <32000 :
            b[i] = 3343
            
        elif e[i]>= 32000 and e[i] <33000 :
            b[i] = 1487
            
        elif e[i]>= 33000 and e[i] <34000 :
            b[i] = 4137
            
        elif e[i]>= 34000 and e[i] <35000 :
            b[i] = 3397
            
        elif e[i]>= 35000 and e[i] <36000 :
            b[i] = 3627
            
        elif e[i]>= 36000 and e[i] <37000 :
            b[i] = 1235
            
        elif e[i]>= 37000 and e[i] <38000 :
            b[i] = 2502
            
        elif e[i]>= 38000 and e[i] <39000 :
            b[i] = 2686
            
        elif e[i]>= 39000 and e[i] <40000 :
            b[i] = 1567
            
        elif e[i]>= 40000 and e[i] <41000 :
            b[i] = 3954
        
        elif e[i]>= 41000 and e[i] <42000 :
            b[i] = 1507
            
        elif e[i]>= 42000 and e[i] <43000 :
            b[i] =1546
            
        elif e[i]>= 43000 and e[i] <44000 :
            b[i] = 1519
            
        elif e[i]>= 44000 and e[i] <45000 :
            b[i] = 3950
            
        elif e[i]>= 45000 and e[i] <46000 :
            b[i] = 2180
            
        elif e[i]>= 46000 and e[i] <47000 :
            b[i] = 1468
            
        elif e[i]>= 47000 and e[i] <48000 :
            b[i] = 1530
            
        elif e[i]>= 48000 and e[i] <49000 :
            b[i] = 1501
            
        elif e[i]>= 49000 and e[i] <50000 :
            b[i] = 2913
            
        elif e[i]>= 50000 and e[i] <51000 :
            b[i] = 2369
            
        elif e[i]>= 51000 and e[i] <52000 :
            b[i] = 2382
            
        elif e[i]>= 52000 and e[i] <53000 :
            b[i] = 1201
            
        elif e[i]>= 53000 and e[i] <54000 :
            b[i] = 1951
            
        elif e[i]>= 54000 and e[i] <55000 :
            b[i] = 1973
            
        elif e[i]>= 55000 and e[i] <56000 :
            b[i] = 1231
            
        elif e[i]>= 56000 and e[i] <57000 :
            b[i] = 3428
            
        elif e[i]>= 57000 and e[i] <58000 :
            b[i] = 1940
            
        elif e[i]>= 58000 and e[i] <59000 :
            b[i] = 1020
            
        elif e[i]>= 59000 and e[i] <60000 :
            b[i] = 2619
            
        elif e[i]>= 60000 and e[i] <61000 :
            b[i] = 2294
            
        elif e[i]>= 61000 and e[i] <62000 :
            b[i] = 1547
            
        elif e[i]>= 62000 and e[i] <63000 :
            b[i] = 2433
            
        elif e[i]>= 63000 and e[i] <64000 :
            b[i] = 2215
            
        elif e[i]>= 64000 and e[i] <65000 :
            b[i] = 4323
            
        elif e[i]>= 65000 and e[i] <66000 :
            b[i] = 1846
            
        elif e[i]>= 66000 and e[i] <67000 :
            b[i] = 2364
            
        elif e[i]>= 67000 and e[i] <68000 :
            b[i] = 3244
            
        elif e[i]>= 68000 and e[i] <69000 :
            b[i] = 1874
            
        elif e[i]>= 69000 and e[i] <70000 :
            b[i] = 4275
            
        elif e[i]>= 70000 and e[i] <71000 :
            b[i] = 1136
            
        elif e[i]>= 71000 and e[i] <72000 :
            b[i] = 1363
            
        elif e[i]>= 72000 and e[i] <73000 :
            b[i] = 1705
            
        elif e[i]>= 73000 and e[i] <74000 :
            b[i] = 4446
            
        elif e[i]>= 74000 and e[i] <75000 :
            b[i] =4604
            
        elif e[i]>= 75000 and e[i] <76000 :
            b[i] = 10346
            
        elif e[i]>= 76000 and e[i] <77000 :
            b[i] = 2266
            
        elif e[i]>= 77000 and e[i] <78000 :
            b[i] = 3391
            
        elif e[i]>= 78000 and e[i] <79000 :
            b[i] = 4977
            
        elif e[i]>= 79000 and e[i] <80000 :
            b[i] = 1684
            
        elif e[i]>= 80000 and e[i] <81000 :
            b[i] = 2354
            
        elif e[i]>= 81000 and e[i] <82000 :
            b[i] = 1740
            
        elif e[i]>= 82000 and e[i] <83000 :
            b[i] = 1707
            
        elif e[i]>= 83000 and e[i] <84000 :
            b[i] = 4107
            
        elif e[i]>= 84000 and e[i] <85000 :
            b[i] = 2347
            
        elif e[i]>= 85000 and e[i] <86000 :
            b[i] = 3188
            
        elif e[i]>= 86000 and e[i] <87000 :
            b[i] = 2182
            
        elif e[i]>= 87000 and e[i] <88000 :
            b[i] = 1817
            
        elif e[i]>= 88000 and e[i] <89000 :
            b[i] = 1579
            
        elif e[i]>= 89000 and e[i] <90000 :
            b[i] = 1348
            
        elif e[i]>= 90000 and e[i] <91000 :
            b[i] = 1403
            
        elif e[i]>= 91000 and e[i] <92000 :
            b[i] = 3288
            
        elif e[i]>= 92000 and e[i] <93000 :
            b[i] = 7250
            
        elif e[i]>= 93000 and e[i] <94000 :
            b[i] = 4539
            
        elif e[i]>= 94000 and e[i] <95000 :
            b[i] = 5622
            
        elif e[i]>= 95000 and e[i] <96000 :
            b[i] = 3519

            

X_test.insert(1,"prix_size", 0)  
e= X_test["prix_size"]
f= X_test["prix_par_m2"]
s = X_test["size"]

for i in range (0,len(X_test['size'])): ## PRIX MOYEN DE LA SUPERFICIE 
    e[i] = f[i] * s[i]


#------- Codage de la variable property type ---------

# Calcul des prix median par type de propriété

filtre_maison = X_train['property_type'] == 'maison'
maison = X_train.loc[filtre_maison]
median_price_maison = maison['price'].median()
#print('prix moyen maison : ',median_price_maison)

filtre_appartement = X_train['property_type'] == 'appartement'
appartement = X_train.loc[filtre_appartement]
median_price_appartement = appartement['price'].median()
#print('prix moyen appartement : ',median_price_appartement)

filtre_propriété = X_train['property_type'] == 'propriété'
propriété = X_train.loc[filtre_propriété]
median_price_propriété = propriété['price'].median()
#print('prix moyen propriété : ',median_price_propriété)

filtre_divers = X_train['property_type'] == 'divers'
divers = X_train.loc[filtre_divers]
median_price_divers = divers['price'].median()
#print('prix moyen divers : ',median_price_divers)

filtre_terrain = X_train['property_type'] == 'terrain'
terrain = X_train.loc[filtre_terrain]
median_price_terrain = terrain['price'].median()
#print('prix moyen terrain : ',median_price_terrain)

filtre_villa = X_train['property_type'] == 'villa'
villa = X_train.loc[filtre_villa]
median_price_villa = villa['price'].median()
#print('prix moyen villa : ',median_price_villa)

filtre_terrain_à_bâtir = X_train['property_type'] == 'terrain à bâtir'
terrain_à_bâtir = X_train.loc[filtre_terrain_à_bâtir]
median_price_terrain_à_bâtir = terrain_à_bâtir['price'].median()
#print('prix moyen terrain_à_bâtir : ',median_price_terrain_à_bâtir)

filtre_duplex = X_train['property_type'] == 'duplex'
duplex = X_train.loc[filtre_duplex]
median_price_duplex = duplex['price'].median()
#print('prix moyen duplex : ',median_price_duplex)

filtre_péniche = X_train['property_type'] == 'péniche'
péniche = X_train.loc[filtre_péniche]
median_price_péniche = péniche['price'].median()
#print('prix moyen péniche : ',median_price_péniche)

filtre_loft = X_train['property_type'] == 'loft'
loft = X_train.loc[filtre_loft]
median_price_loft = loft['price'].median()
#print('prix moyen loft : ',median_price_loft)

filtre_parking = X_train['property_type'] == 'parking'
parking = X_train.loc[filtre_parking]
median_price_parking = parking['price'].median()
#print('prix moyen parking : ',median_price_parking)

filtre_moulin = X_train['property_type'] == 'moulin'
moulin = X_train.loc[filtre_moulin]
median_price_moulin = moulin['price'].median()
#print('prix moyen moulin : ',median_price_moulin)

filtre_château = X_train['property_type'] == 'château'
château = X_train.loc[filtre_château]
median_price_château = château['price'].median()
#print('prix moyen château : ',median_price_château)

filtre_manoir = X_train['property_type'] == 'manoir'
manoir = X_train.loc[filtre_manoir]
median_price_manoir = manoir['price'].median()
#print('prix moyen manoir : ',median_price_manoir)

filtre_viager = X_train['property_type'] == 'viager'
viager = X_train.loc[filtre_viager]
median_price_viager = viager['price'].median()
#print('prix moyen viager : ',median_price_viager)

filtre_chalet = X_train['property_type'] == 'chalet'
chalet = X_train.loc[filtre_chalet]
median_price_chalet = chalet['price'].median()
#print('prix moyen chalet : ',median_price_chalet)

filtre_chambre = X_train['property_type'] == 'chambre'
chambre = X_train.loc[filtre_chambre]
median_price_chambre = chambre['price'].median()
#print('prix moyen chambret : ',median_price_chambre)

filtre_ferme = X_train['property_type'] == 'ferme'
ferme = X_train.loc[filtre_ferme]
median_price_ferme = ferme['price'].median()
#print('prix moyen ferme : ',median_price_ferme)

filtre_hôtel_particulier = X_train['property_type'] == 'hôtel particulier'
hôtel_particulier = X_train.loc[filtre_hôtel_particulier]
median_price_hôtel_particulier = hôtel_particulier['price'].median()
#print('prix moyen hôtel particulier : ',median_price_hôtel_particulier)

filtre_gîte = X_train['property_type'] == 'gîte'
gîte = X_train.loc[filtre_gîte]
median_price_gîte = gîte['price'].median()
#print('prix moyen gîte : ',median_price_gîte)


# implémentation

X_test.insert(1,'price_pred',0)

a = X_test['property_type']
b = X_test['price_pred']

for i in range (0,len(X_test['property_type'])):
    if a[i] == 'maison':
        b[i] = median_price_maison
        
    elif a[i] == 'appartement':
        b[i] = median_price_appartement
        
    elif a[i] == 'maison':
        b[i] = median_price_maison

        
    elif a[i] == 'propriété':
        b[i] = median_price_propriété

        
    elif a[i] == 'divers':
        b[i] = median_price_divers
        
    elif a[i] == 'villa':
        b[i] = median_price_villa
        
    elif a[i] == 'terrain':
        b[i] = median_price_terrain
        
    elif a[i] == 'terrain à bâtir':
        b[i] = median_price_terrain_à_bâtir
        
    elif a[i] == 'duplex':
        b[i] = median_price_duplex
        
    elif a[i] == 'péniche':
        b[i] = median_price_péniche
        
    elif a[i] == 'loft':
        b[i] = median_price_loft
        
    elif a[i] == 'parking':
        b[i] = median_price_parking
        
    elif a[i] == 'moulin':
        b[i] = median_price_moulin
        
    elif a[i] == 'château':
        b[i] = median_price_château
        
    elif a[i] == 'manoir':
        b[i] = median_price_manoir
        
    elif a[i] == 'viager':
        b[i] = median_price_viager

    elif a[i] == 'chalet':
        b[i] = median_price_chalet
        
    elif a[i] == 'chambre':
        b[i] = median_price_chambre
        
    elif a[i] == 'ferme':
        b[i] = median_price_ferme
        
    elif a[i] == 'gîte':
        b[i] = median_price_gîte
        
    elif a[i] == 'hôtel particulier':
        b[i] = median_price_hôtel_particulier
        
#---
        
X_train.insert(1,'price_pred',0)

a = X_train['property_type']
b = X_train['price_pred']

for i in range (0,len(X_train['property_type'])):
    if a[i] == 'maison':
        b[i] = median_price_maison
        
    elif a[i] == 'appartement':
        b[i] = median_price_appartement
        
    elif a[i] == 'maison':
        b[i] = median_price_maison

        
    elif a[i] == 'propriété':
        b[i] = median_price_propriété

        
    elif a[i] == 'divers':
        b[i] = median_price_divers
        
    elif a[i] == 'villa':
        b[i] = median_price_villa
        
    elif a[i] == 'terrain':
        b[i] = median_price_terrain
        
    elif a[i] == 'terrain à bâtir':
        b[i] = median_price_terrain_à_bâtir
        
    elif a[i] == 'duplex':
        b[i] = median_price_duplex
        
    elif a[i] == 'péniche':
        b[i] = median_price_péniche
        
    elif a[i] == 'loft':
        b[i] = median_price_loft
        
    elif a[i] == 'parking':
        b[i] = median_price_parking
        
    elif a[i] == 'moulin':
        b[i] = median_price_moulin
        
    elif a[i] == 'château':
        b[i] = median_price_château
        
    elif a[i] == 'manoir':
        b[i] = median_price_manoir
        
    elif a[i] == 'viager':
        b[i] = median_price_viager

    elif a[i] == 'chalet':
        b[i] = median_price_chalet
        
    elif a[i] == 'chambre':
        b[i] = median_price_chambre
        
    elif a[i] == 'ferme':
        b[i] = median_price_ferme
        
    elif a[i] == 'gîte':
        b[i] = median_price_gîte
        
    elif a[i] == 'hôtel particulier':
        b[i] = median_price_hôtel_particulier
        
#------- Suppression des données non voulues -----------

X_train = X_train.merge(y_train, on='id_annonce')

X_train = X_train.drop(['approximate_latitude', 'energy_performance_category', 'ghg_category',
                       'exposition', 'approximate_longitude', 'property_type', 'last_floor',
                       'city', 'postal_code','upper_floors','id_annonce','floor','nb_rooms', 'nb_parking_places' , 'nb_boxes'
                        ,'has_a_cellar' , 'has_a_garage' ,'nb_bathrooms','nb_bedrooms','prix_par_m2' ,   'size' , 'land_size','energy_performance_value','ghg_value' ,'has_air_conditioning' , 'nb_photos',  'has_a_balcony' , 'nb_terraces' ,  'price_y' ], axis =1)


X_test = X_test.drop(['approximate_latitude', 'energy_performance_category', 'ghg_category',
                       'exposition', 'approximate_longitude', 'property_type', 'last_floor',
                       'city', 'postal_code','upper_floors','id_annonce','floor','nb_rooms', 'nb_parking_places' , 'nb_boxes'
                        ,'has_a_cellar' , 'has_a_garage' ,'prix_par_m2' ,   'size' , 'land_size','nb_bathrooms','nb_bedrooms','energy_performance_value','ghg_value' ,'has_air_conditioning' , 'nb_photos',  'has_a_balcony' , 'nb_terraces'  ], axis =1)


######################################  REGRESSION ########################################

X, y = X_train.iloc[:,:-1],X_train.iloc[:,-1]

data_dmatrix = xgb.DMatrix(data=X,label=y)

from sklearn.model_selection import train_test_split

X_train, X_test0, y_train, y_test = train_test_split(X, y,train_size = None, test_size= None , random_state=123)

xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 1, learning_rate = 0.4,
                max_depth = 20, alpha = 0.0001, n_estimators = 30)

xg_reg.fit(X_train,y_train)

preds = xg_reg.predict(X_test)

#----------- Création du DataFrame de résultat --------------------

submission = pd.DataFrame({'id_annonce':X_test2['id_annonce'], 'price':preds[0:9339]})
submission.to_csv("resultat.csv", index= False)

print('done')
# Out:
# ...
# [17:27:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# done
